# %%
import json
from tqdm import tqdm

# %% [markdown]
# ## 处理数据集
#
# 处理交互信息

# %%
file = "D:\Code\graduation_design\data\Toys_and_Games\Toys_and_Games.jsonl"
with open(file, 'r') as fp:
    for line in tqdm(fp):
        data = json.loads(line.strip())
        user_id = data['user_id']
        item_id = data['asin'] 
        rating = data['rating']
        timestamp = data['timestamp']

        with open('D:/Code/graduation_design/data/Toys_and_Games/interaction.dat', 'a') as f:
            f.write(f"{user_id},{item_id},{rating},{timestamp}\n")
# Out:
# 16260406it [52:33, 5156.09it/s]

# %% [markdown]
# 处理物品信息

# %%
file = "D:\Code\graduation_design\data\Toys_and_Games\meta_Toys_and_Games.jsonl"
with open(file, 'r') as fp:
    for line in tqdm(fp):
        data = json.loads(line.strip())
        if data['parent_asin'] in items1:
            data['parent_asin'] = item_to_id[data['parent_asin']]
            with open('D:/Code/graduation_design/data/Toys_and_Games/item.csv', 'a') as f:
                f.write(f"{json.dumps(data)}\n")
# Out:
# 0it [00:00, ?it/s]
# 890874it [10:56, 1356.56it/s]

# %% [markdown]
# ## 验证数据集

# %%
import pandas as pd
df = pd.read_csv("D:/Code/graduation_design/data/Toys_and_Games/interaction.dat", sep=",", header=None, engine='python')
df.columns = ['user', 'item', 'rating', 'timestamp']
df
# Out:
#                                   user        item  rating      timestamp
# 0         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  B09QH7QJS7     5.0  1677939664713
# 1         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  B06XYKSKQP     3.0  1639855230760
# 2         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  B07SFF3YQW     5.0  1580949719154
# 3         AGKASBHYZPGTEPO6LWZPVJWB2BVA  B007JWWUDW     5.0  1471542588000
# 4         AGKASBHYZPGTEPO6LWZPVJWB2BVA  B00MZG6OO8     3.0  1471541996000
# ...                                ...         ...     ...            ...
# 16260401  AETW5EVUAA26OZTJTE3F6UAYVRKQ  B00I2EK28G     5.0  1454984530000
# 16260402  AEZ6O5JDOUHI3CSQ6EZWZJ7K3BDQ  B00I2EK28G     5.0  1563409419712
# 16260403  AGCHMLXSAABU5L7BTJNT3554GITQ  B00DIH6WFE     5.0  1578620090607
# 16260404  AF2C3GZUUADH7UQBWYW5DBHI2NBQ  B00I2EK28G     5.0  1451931432000
# 16260405  AGQ2UCOLPYUGHSSHVRZ5BKLUYHZQ  B09K79H22D     1.0  1649463719102
#
# [16260406 rows x 4 columns]

# %%
data = df[df['rating'] > 2]

item_counts = data['item'].value_counts()
items_to_keep = item_counts[item_counts >= 50].index
data = data[data['item'].isin(items_to_keep)]

user_counts = data['user'].value_counts()
users_to_keep = user_counts[user_counts >= 20].index
data = data[data['user'].isin(users_to_keep)]

print(f"用户数量: {len(data['user'].unique())}, 物品数量: {len(data['item'].unique())}")

data = data.sort_values(['user', 'timestamp'])
data = data.reset_index(drop=True)
data
# Out:
# 用户数量: 7356, 物品数量: 39755
#                                 user        item  rating      timestamp
# 0       AE226IHCMYPYN4AIZKNRVH7ETC4A  B01LX4YRB5     5.0  1520298017600
# 1       AE226IHCMYPYN4AIZKNRVH7ETC4A  B00NHQIR2C     5.0  1520298044179
# 2       AE226IHCMYPYN4AIZKNRVH7ETC4A  B00NHQGGXY     5.0  1520298050422
# 3       AE226IHCMYPYN4AIZKNRVH7ETC4A  B00IRXJ972     5.0  1594321903084
# 4       AE226IHCMYPYN4AIZKNRVH7ETC4A  B008BM2LJ2     5.0  1595115948985
# ...                              ...         ...     ...            ...
# 222841  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B07PMN4NJD     4.0  1579522416263
# 222842  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B08HN1QPW1     4.0  1605880799457
# 222843  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B08L9NRGX2     4.0  1608575056788
# 222844  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B08J3ZP7ZJ     4.0  1611930532109
# 222845  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B08DCNWY3N     4.0  1619611232873
#
# [222846 rows x 4 columns]

# %%
df_filtered = data[data['item'].isin(true_items)]
print(f"用户数量: {len(df_filtered['user'].unique())}, 物品数量: {len(df_filtered['item'].unique())}")
df_filtered
# Out:
# 用户数量: 7356, 物品数量: 27907
#                                 user        item  rating      timestamp
# 0       AE226IHCMYPYN4AIZKNRVH7ETC4A  B01LX4YRB5     5.0  1520298017600
# 1       AE226IHCMYPYN4AIZKNRVH7ETC4A  B00NHQIR2C     5.0  1520298044179
# 2       AE226IHCMYPYN4AIZKNRVH7ETC4A  B00NHQGGXY     5.0  1520298050422
# 3       AE226IHCMYPYN4AIZKNRVH7ETC4A  B00IRXJ972     5.0  1594321903084
# 4       AE226IHCMYPYN4AIZKNRVH7ETC4A  B008BM2LJ2     5.0  1595115948985
# ...                              ...         ...     ...            ...
# 222830  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B07H7J5K3F     4.0  1546631370839
# 222832  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B07LD3QV8Q     4.0  1553535657785
# 222834  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B07Q1K1YZZ     4.0  1567103994153
# 222841  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B07PMN4NJD     4.0  1579522416263
# 222842  AHZZOHPNU4KMDHG2QUM23TNROCCQ  B08HN1QPW1     4.0  1605880799457
#
# [149038 rows x 4 columns]

# %%
unique_users = df_filtered['user'].unique()
unique_items = df_filtered['item'].unique()

user_to_id = {user: i for i, user in enumerate(unique_users)}
item_to_id = {item: i for i, item in enumerate(unique_items)}
id_to_user = {i: user for user, i in user_to_id.items()}
id_to_item = {i: item for item, i in item_to_id.items()}

n_user = len(user_to_id)
n_item = len(item_to_id)

# 添加ID列到数据中
df_filtered['user_id'] = df_filtered['user'].map(user_to_id)
df_filtered['item_id'] = df_filtered['item'].map(item_to_id)
df_filtered
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8236\286750220.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['user_id'] = df_filtered['user'].map(user_to_id)
# C:\Users\dell\AppData\Local\Temp\ipykernel_8236\286750220.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['item_id'] = df_filtered['item'].map(item_to_id)
#                                 user        item  rating      timestamp  \
# ...

# %%
item_to_id
# Out:
# {'B01LX4YRB5': 0,
#  'B00NHQIR2C': 1,
#  'B00NHQGGXY': 2,
#  'B00IRXJ972': 3,
#  'B008BM2LJ2': 4,
#  'B078C9LXCM': 5,
#  'B00NHQGGM0': 6,
#  'B00PS1D5KI': 7,
#  'B00PS1GKDW': 8,
#  'B00ND5ZP3G': 9,
#  'B00DOQCTVK': 10,
#  'B00HLV78TW': 11,
#  'B00ND5ZWPM': 12,
#  'B00B8ECDK2': 13,
#  'B00CQHZ2LW': 14,
#  'B016CEXS06': 15,
#  'B000F3V2R2': 16,
#  'B00FZMDAL4': 17,
#  'B01IWEX7ZK': 18,
#  'B07DLLP2ZH': 19,
#  'B06XT845H1': 20,
#  'B01NBKYBTG': 21,
#  'B07KVMTTDR': 22,
#  'B07X3YF873': 23,
#  'B08DRCYP2F': 24,
#  'B01NBQW3BP': 25,
#  'B08C7SK4R5': 26,
#  'B000IDOPDC': 27,
#  'B00CPHX6YI': 28,
#  'B0036WSVQ4': 29,
#  'B074VFQGP3': 30,
#  'B016NY029K': 31,
#  'B00SUSUVSK': 32,
#  'B004K6KM9E': 33,
#  'B01LY43OPA': 34,
#  'B016NY03DA': 35,
#  'B00BN4QVF0': 36,
#  'B074XB3S8F': 37,
#  'B016IFLMK2': 38,
#  'B0027YRSFC': 39,
#  'B07WJJF8PB': 40,
#  'B00BN6QAWM': 41,
#  'B01AD1TDZ8': 42,
#  'B01ATCA4CW': 43,
#  'B01K9WEM2A': 44,
#  'B07RXMV6PT': 45,
#  'B07QWVM5J4': 46,
#  'B07WHF7H2F': 47,
# ...

# %%
selected_columns = df_filtered[['user_id', 'item_id', 'rating', 'timestamp']]
selected_columns.to_csv("D:/Code/graduation_design/data/Toys_and_Games/new_interaction.csv", index=False)

# %%
import pandas as pd

items = pd.read_csv("D:/Code/graduation_design/data/Office_Products/item.dat", sep=",", names=['itemId', 'json'], engine='python', header=None)
print(items.head())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File f:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\pandas\io\parsers\python_parser.py:795, in PythonParser._next_iter_line(self, row_num)
#     794 assert self.data is not None
# --> 795 line = next(self.data)
#     796 # for mypy
#
# Error: ',' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[83], line 3
#       1 import pandas as pd
# ----> 3 items = pd.read_csv("D:/Code/graduation_design/data/Office_Products/item.dat", sep=",", names=['itemId', 'json'], engine='python', header=None)
#       4 print(items.head())
#
# ...

# %%
item_title = items['json'].apply(lambda x: json.loads(x)['title'])
item_entities = [[str(itemId), str(title)] for itemId, title in zip(items['itemId'], item_title)]
item_entities
# Out:
# [['B001S28Q4Q',
#   'Alliance Rubber 07706 Non-Latex Brites File Bands, Colored Elastic Bands, 1.5 oz Pic Pac Dispenser (Assorted Bright Colors and Sizes)'],
#  ['B07RPQVH21',
#   '10 Set Mini Office Stapler with 10# Staples, Small Hand Stapler Portable Desktop Stapler Student Stapler'],
#  ['B07J58B87Q',
#   'Creanoso Humorous Sayings Bookish Bookmarks for Men & Women (30-Pack) –– Stocking Stuffers Gift for Bibliophiles, Book Worms, Book Lovers – Party Supplies – Book Clubs Reading'],
#  ['B098NQ685V',
#   'PenPower WorldPen Scan Go | OCR Reading Pen with Text to Speech | Pen Scanner for Data Input | Pen Translator for Second Language Learners| Wireless Standalone | LCD Touchscreen | Wi-Fi Connection'],
#  ['B00DBSNIC0',
#   'Assorted Best Selling Birthday Cards, Set of 8 Greeting Cards'],
#  ['B0771YCWND', 'Paperkraft Handmade Rose Bouquet 3D Pop Up Greeting Card'],
#  ['B00URTWH7S',
# ...

# %% [markdown]
# ## 把处理之后用到的item提取出来

# %%
import pandas as pd
df = pd.read_csv("D:/Code/graduation_design/data/Toys_and_Games/new_interaction.csv", sep=",", header=None, engine='python')
df.columns = ['user', 'item', 'rating', 'timestamp']
df['item'].unique()
# Out:
# array([    0,     1,     2, ..., 27904, 27905, 27906], dtype=int64)

# %%
import pandas as pd
df = pd.read_csv("D:/Code/graduation_design/data/Office_Products/interaction.dat", sep=",", header=None, engine='python')
df.columns = ['user', 'item', 'rating', 'timestamp']
df['item'].unique()
# Out:
# array(['B007QFATEO', 'B000AN1QDM', 'B0007L1VLO', ..., 'B09Q33PRQG',
#        'B0B6KWGWR7', 'B0BKR2ZR9F'], dtype=object)

# %%
item_values = df['item'].unique()
item_values, item_values.shape
# Out:
# (array(['B007QFATEO', 'B000AN1QDM', 'B0007L1VLO', ..., 'B09Q33PRQG',
#         'B0B6KWGWR7', 'B0BKR2ZR9F'], dtype=object),
#  (3625,))

# %%
items1 = df_filtered['item'].unique()
items1
# Out:
# array(['B01LX4YRB5', 'B00NHQIR2C', 'B00NHQGGXY', ..., 'B00IHZZOCO',
#        'B083Y7786C', 'B000BNLVBS'], dtype=object)

# %%
file = "D:/Code/graduation_design/data/Toys_and_Games/meta_Toys_and_Games.jsonl"
items2 = []
with open(file, 'r') as fp:
    for line in tqdm(fp):
        data = json.loads(line.strip())
        parent_asin = data['parent_asin']
        items2.append(parent_asin)
# Out:
# 890874it [00:15, 56075.00it/s]

# %%
len(item_to_id)
# Out:
# 39755

# %%
true_items = set(items1) & set(items2)
true_items == set(items1)
# Out:
# True

# %%
df
# Out:
#         user   item  rating      timestamp
# 0          0      0     5.0  1520298017600
# 1          0      1     5.0  1520298044179
# 2          0      2     5.0  1520298050422
# 3          0      3     5.0  1594321903084
# 4          0      4     5.0  1595115948985
# ...      ...    ...     ...            ...
# 222841  7355   8284     4.0  1579522416263
# 222842  7355  12536     4.0  1605880799457
# 222843  7355  35819     4.0  1608575056788
# 222844  7355  36837     4.0  1611930532109
# 222845  7355  10154     4.0  1619611232873
#
# [222846 rows x 4 columns]

# %%
df_filtered = df[df['item'].isin(true_items)]
df_filtered
# Out:
# Empty DataFrame
# Columns: [user, item, rating, timestamp]
# Index: []
